# %% [markdown]
# Import Dependencies

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load and Analyze Data

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv('Employee_Data.csv')

print("First 5 rows of the dataset:")
display(df.head())

print("Data types of the columns:")
display(df.dtypes)

print("Summary statistics of the dataset:")
display(df.describe(include='all').T)
# Out:
# First 5 rows of the dataset:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %% [markdown]
# Dropping Null and Duplicate Values

# %%
print("Dropping null values:")
df.dropna(inplace=True)
print("Checking for null values after dropping:")
display(df.info())

print("Dropping duplicates:")
df.drop_duplicates(inplace=True)
print("Checking for duplicates after dropping:")
display(df.duplicated().sum())
# Out:
# Dropping null values:
# Checking for null values after dropping:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
# ...

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# Encoding Categorical Data for Analysis

# %%
# Department
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Department', palette='Set2')
plt.title('Employees in Each Department')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Education Levels
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Education', palette='Set2')
plt.title('Education Level of Employees')
plt.xlabel('Education Level (1:, 2:, 3:, 4:, 5:)')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Education Field
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='EducationField', palette='Set2')
plt.title('Education Fields of Employees')
plt.xlabel('Education Fields')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

#Business Travel
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='BusinessTravel', palette='Set2')
plt.title('Business Travel Frequency')
plt.xlabel('Business Travel Frequency')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

#Gender
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Gender', palette='Set2')
plt.title('Employee Genders')
plt.xlabel('Genders')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

#Job Involvement
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='JobInvolvement', palette='Set2')
plt.title('Job Involvement Levels')
plt.xlabel('Job Involvement Levels (1:Low, 2:Med, 3:High, 4:Very High)')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

#Job Role
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='JobRole', palette='Set2')
plt.title('Job Roles')
plt.xlabel('Job Roles')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

#Job Level
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='JobLevel', palette='Set2')
plt.title('Job Levels(1:, 2:, 3:, 4:, 5:)')
plt.xlabel('Job Levels')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

#Job Satisfaction
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='JobSatisfaction', palette='Set2')
plt.title('Job Satisfaction Levels(1:Low, 2:Med, 3:High, 4:Very High)')
plt.xlabel('Job Satisfaction Levels')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

#Work-Life Balance
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='WorkLifeBalance', palette='Set2')
plt.title('Work-Life Balance(1:Bad, 2:Good, 3:Better, 4:Best)')
plt.xlabel('Work-Life Balance Levels')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Environmental Satisfaction
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='EnvironmentSatisfaction', palette='Set2')
plt.title('	Environmental Satisfaction(1: None, 2: Low, 3: Moderate, 4: High, 5: Very High)')
plt.xlabel('Environmental Satisfaction Levels')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Attrition Rate
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Attrition', palette='Set2')
plt.title('Attrition Rate of Employees')
plt.xlabel('Attrition Rate (1:Yes, 0:No)')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Marital Status
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='MaritalStatus', palette='Set2')
plt.title('Marital Status of Employees')
plt.xlabel('Marital Status')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Over Time
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='OverTime', palette='Set2')
plt.title('Over Time Status of Employees')
plt.xlabel('OverTime')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Performance Rating
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='PerformanceRating', palette='Set2')
plt.title('Performance Rating of Employees(1:Low, 2:Med, 3:High, 4:Very High)')
plt.xlabel('Performance Rating')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Stock Option Level
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='StockOptionLevel', palette='Set2')
plt.title('Stock Option Levels of Employees(1:Low, 2:Med, 3:High, 4:Very High)')
plt.xlabel('Stock Option Level')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# Relationship Satisfaction
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='RelationshipSatisfaction', palette='Set2')
plt.title('Relationship Satisfaction of Employees(1:Low, 2:Med, 3:High, 4:Very High)')
plt.xlabel('Relationship Satisfaction')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\thian\AppData\Local\Temp\ipykernel_19644\1267517681.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Department', palette='Set2')
# C:\Users\thian\AppData\Local\Temp\ipykernel_19644\1267517681.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Education', palette='Set2')
# C:\Users\thian\AppData\Local\Temp\ipykernel_19644\1267517681.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='EducationField', palette='Set2')
# ...

# %% [markdown]
# HistoPlots

# %%
# Age Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df['Age'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Age Distribution of Employees')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Number of Employees')

# Monthly Income Distribution
sns.histplot(df['MonthlyIncome'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Monthly Income Distribution of Employees')
axes[1].set_xlabel('Monthly Income')
axes[1].set_ylabel('Number of Employees')

# Hourly Rate Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df['HourlyRate'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Hourly Rate Distribution of Employees')
axes[0].set_xlabel('Hourly Rate')
axes[0].set_ylabel('Number of Employees')

# Daily rate Distribution
sns.histplot(df['DailyRate'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Daily Rate Distribution of Employees')
axes[1].set_xlabel('Daily Rate')
axes[1].set_ylabel('Number of Employees')

# Monthly rate Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df['MonthlyRate'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Monthly Rate Distribution of Employees')
axes[0].set_xlabel('Monthly Rate')
axes[0].set_ylabel('Number of Employees')

# Salary Hike Distribution
sns.histplot(df['PercentSalaryHike'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Salary Hike Percentage Distribution of Employees')
axes[1].set_xlabel('Salary Hike Percentage')
axes[1].set_ylabel('Number of Employees')

# Distance from Work Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df['DistanceFromHome'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Distance from Work Distribution of Employees')
axes[0].set_xlabel('Distance from Work')
axes[0].set_ylabel('Number of Employees')

# Years at Company Distribution
sns.histplot(df['YearsAtCompany'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Years at Company Distribution of Employees')
axes[1].set_xlabel('Years at Company')
axes[1].set_ylabel('Number of Employees')

# Years Since Last Promotion Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df['YearsSinceLastPromotion'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Years since last Promotion Distribution of Employees')
axes[0].set_xlabel('Years since last Promotion')
axes[0].set_ylabel('Number of Employees')

# Working Years Distribution
sns.histplot(df['TotalWorkingYears'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Total Working Years Distribution of Employees')
axes[1].set_xlabel('TotalWorkingYears')
axes[1].set_ylabel('Number of Employees')

# Companies Worked For Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df['NumCompaniesWorked'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Number of Companies Worked For Distribution of Employees')
axes[0].set_xlabel('Number of Companies Worked For')
axes[0].set_ylabel('Number of Employees')

# Distance From Home Distribution
sns.histplot(df['DistanceFromHome'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Distance From Home Distribution of Employees')
axes[1].set_xlabel('Distance From Home')
axes[1].set_ylabel('Number of Employees')

# Training Times Last Year Distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.histplot(df['TrainingTimesLastYear'], bins=20, kde=True, ax=axes[0])
axes[0].set_title('Training Times Previous Year Distribution of Employees')
axes[0].set_xlabel('Training Times Previous Year')
axes[0].set_ylabel('Number of Employees')

# Years with Current Manager Distribution
sns.histplot(df['YearsWithCurrManager'], bins=20, kde=True, ax=axes[1])
axes[1].set_title('Years with Current Manager Distribution of Employees')
axes[1].set_xlabel('Years with Current Manager')
axes[1].set_ylabel('Number of Employees')
# Out:
# Text(0, 0.5, 'Number of Employees')

# %% [markdown]
# BoxPlots

# %%
 # Function to remove outliers using IQR
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# List of numerical variables for boxplots
numerical_vars = [
    'Age', 'MonthlyIncome', 'HourlyRate', 'DailyRate', 'MonthlyRate',
    'PercentSalaryHike', 'DistanceFromHome', 'YearsAtCompany',
    'YearsSinceLastPromotion', 'TotalWorkingYears', 'NumCompaniesWorked',
    'TrainingTimesLastYear', 'YearsWithCurrManager'
]

# Plot boxplots without outliers
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(16, 28))
axes = axes.flatten()

for i, var in enumerate(numerical_vars):
    cleaned_df = remove_outliers_iqr(df, var)
    sns.boxplot(y=cleaned_df[var], ax=axes[i], color='lightgreen')
    axes[i].set_title(f'Boxplot of {var} (Outliers Removed)')
    axes[i].set_xlabel('')
    axes[i].set_ylabel(var)

# Hide unused subplot if odd number of plots
if len(numerical_vars) % 2 != 0:
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
### Correlation Matrix
plt.figure(figsize=(20, 12))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Dividing Features into Numerical and Categorical

# %%
discrete_features = ['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
                 'PercentSalaryHike', 'StandardHours', 'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany', 
                 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

categorical_features = ['Attrition', 'BusinessTravel','Department', 'Education', 'EducationField', 'EmployeeCount','EmployeeNumber',
                    'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
                    'MaritalStatus', 'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
                    'WorkLifeBalance']

df1 = df.copy(deep = True)

# %%
colors = ['#2BAE66','#FCF6F5']
#for i in range(5):
    #fig, ax = plt.subplots(nrows = 1,ncols = 3,figsize = (15,3))
    #a = 1
    #for j in discrete_features[(i*3) : (i*3) + 3]:
       # plt.subplot(1,3,a) 
       # sns.distplot(df1[j],kde_kws = {'bw' : 1},color = colors[0]);
       # plt.title('Distribution : ' + j)
       # a += 1

# %% [markdown]
# Numerical vs Attrition: Boxplots

# %%
numerical_vars = [
    'Age', 'MonthlyIncome', 'HourlyRate', 'DailyRate', 'MonthlyRate',
    'PercentSalaryHike', 'DistanceFromHome', 'YearsAtCompany',
    'YearsSinceLastPromotion', 'TotalWorkingYears', 'NumCompaniesWorked',
    'TrainingTimesLastYear', 'YearsWithCurrManager'
]

# Plot boxplots of numerical features vs Attrition
fig, axes = plt.subplots(nrows=7, ncols=2, figsize=(18, 28))
axes = axes.flatten()

for i, var in enumerate(numerical_vars):
    sns.boxplot(x='Attrition', y=var, data=df, ax=axes[i], palette='Set2')
    axes[i].set_title(f'{var} by Attrition')
    axes[i].set_xlabel('Attrition (0 = No, 1 = Yes)')
    axes[i].set_ylabel(var)

if len(numerical_vars) % 2 != 0:
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\thian\AppData\Local\Temp\ipykernel_19644\664630766.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=var, data=df, ax=axes[i], palette='Set2')
# C:\Users\thian\AppData\Local\Temp\ipykernel_19644\664630766.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=var, data=df, ax=axes[i], palette='Set2')
# C:\Users\thian\AppData\Local\Temp\ipykernel_19644\664630766.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Attrition', y=var, data=df, ax=axes[i], palette='Set2')
# ...

# %% [markdown]
# Categorical vs Attrition: Grouped Barplots

# %%
categorical_vars = [
    'Department', 'Education', 'EducationField', 'BusinessTravel', 'Gender',
    'JobInvolvement', 'JobRole', 'JobLevel', 'JobSatisfaction',
    'WorkLifeBalance', 'EnvironmentSatisfaction', 'MaritalStatus',
    'OverTime', 'PerformanceRating', 'StockOptionLevel', 'RelationshipSatisfaction'
]

# Plot percentage of attrition by each category
for var in categorical_vars:
    plt.figure(figsize=(10, 6))
    attrition_rate = df.groupby(var)['Attrition'].value_counts(normalize=True).unstack().fillna(0)
    attrition_rate['Yes'].plot(kind='bar', color='tomato')
    plt.title(f'Attrition Rate by {var}')
    plt.ylabel('Attrition Rate')
    plt.xlabel(var)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# - Drop Attrition as it is our target variable.
#
# - Also we drop Over18 and Employee count as it is single value features.
#
# - Employee number is a identifier with no repetitive elements and hence we drop that aswell

# %% [markdown]
# Encoding

# %%
mappings = {
            'Attrition': {'Yes': 1, 'No': 0}, 
            'BusinessTravel': {'Travel_Rarely': 0, 'Travel_Frequently': 1, 'Non-Travel': 2},
            'Department': {'Sales': 0, 'Research & Development': 1, 'Human Resources': 2},
            'EducationField': {'Life Sciences': 0, 'Medical': 1, 'Marketing': 2, 'Technical Degree': 3, 'Human Resources': 4, 'Other': 5},
            'Gender': {'Male': 0, 'Female': 1},
            'JobRole': {'Sales Executive': 0, 'Research Scientist': 1, 'Laboratory Technician': 2, 'Manufacturing Director': 3, 'Healthcare Representative': 4, 'Manager': 5, 'Sales Representative': 6, 'Research Director': 7, 'Human Resources': 8, 'Technician': 9},
            'MaritalStatus': {'Single': 0, 'Married': 1, 'Divorced': 2},
            'Over18': {'Y': 1, 'N': 0},
            'OverTime': {'Yes': 1, 'No': 0}
            }

df.replace(mappings, inplace=True)
# Out:
# C:\Users\thian\AppData\Local\Temp\ipykernel_19644\685972519.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(mappings, inplace=True)

# %%
df.drop(columns = ['EmployeeCount', 'EmployeeNumber', 'Over18'], inplace = True)
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               0       1102           0                 1
# 1   49          0               1        279           1                 8
# 2   37          1               0       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               0        591           1                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          2               0                        2       1          94
# 1          1               0                        3       0          61
# 2          2               5                        4       0          92
# 3          4               0                        4       1          56
# 4          1               1                        1       0          40
#
# ...

# %% [markdown]
# ## Feature engineering

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

features = ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
       'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
       'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
       'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
       'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
       'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']

target = 'Attrition'

f1 = df[features]
t1 = df[target]

x_train,x_test,y_train,y_test = train_test_split(f1,t1,test_size = 0.15, random_state=2)

# %%
x_train_test = x_train.copy(deep = True)
x_train_test['Attrition'] = y_train

# %%
corr = x_train_test.corrwith(x_train_test['Attrition']).sort_values(ascending = False).to_frame()
corr.columns = ['Attrition']
plt.subplots(figsize = (7,10))
sns.heatmap(corr,annot = True,cmap = colors,linewidths = 0.4,linecolor = 'black');
plt.title('Correlation w.r.t Attrition');
# Out:
# c:\Users\thian\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\thian\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# - None of the features display a strong positive or negative correlation with Attrition.
# - Most of the features have values between [-0.3 - 0.14].

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif,chi2

# %%
print(categorical_features)
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'WorkLifeBalance']

# %%
from sklearn.feature_selection import f_classif

features = x_train.loc[:,discrete_features]
target = pd.DataFrame(y_train)

best_features = SelectKBest(score_func = f_classif,k = 'all')
fit = best_features.fit(features,target)

featureScores = pd.DataFrame(data = fit.scores_,index = list(features.columns),columns = ['ANOVA Score']) 

plt.subplots(figsize = (5,5))
sns.heatmap(featureScores.sort_values(ascending = False,by = 'ANOVA Score'),annot = True,cmap = colors,linewidths = 0.4,linecolor = 'black',fmt = '.2f');
plt.title('Selection of Numerical Features');
# Out:
# c:\Users\thian\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\thian\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:111: UserWarning: Features [8] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# c:\Users\thian\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %%
x_train = x_train.drop(columns = ['MonthlyRate', 'HourlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 
                                  'YearsSinceLastPromotion', 'DistanceFromHome','DailyRate',
                                  'PerformanceRating', 'Department', 'JobRole', 'EducationField', 
                                  'BusinessTravel', 'MaritalStatus' ,'Gender'])

x_test = x_test.drop(columns = ['MonthlyRate', 'HourlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 
                                  'YearsSinceLastPromotion', 'DistanceFromHome','DailyRate',
                                  'PerformanceRating', 'Department', 'JobRole', 'EducationField', 
                                  'BusinessTravel', 'MaritalStatus' ,'Gender'])

# %% [markdown]
# - Data scaling , we will we using normalisation and standardization. Normalization is done for features whose data does not display normal distribution and standrization is carried out for features whose data is normally distributes but the range is hunge or small compared to other features

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler
mms = MinMaxScaler() # Normalization
ss = StandardScaler() # Standardization

# Normalization
x_train['MonthlyIncome'] = mms.fit_transform(x_train[['MonthlyIncome']]); x_test['MonthlyIncome'] = mms.transform(x_test[['MonthlyIncome']])
x_train['TotalWorkingYears'] = mms.fit_transform(x_train[['TotalWorkingYears']]); x_test['TotalWorkingYears'] = mms.transform(x_test[['TotalWorkingYears']])
x_train['YearsAtCompany'] = mms.fit_transform(x_train[['YearsAtCompany']]); x_test['YearsAtCompany'] = mms.transform(x_test[['YearsAtCompany']])
x_train['YearsInCurrentRole'] = mms.fit_transform(x_train[['YearsInCurrentRole']]); x_test['YearsInCurrentRole'] = mms.transform(x_test[['YearsInCurrentRole']])
x_train['YearsWithCurrManager'] = mms.fit_transform(x_train[['YearsWithCurrManager']]); x_test['YearsWithCurrManager'] = mms.transform(x_test[['YearsWithCurrManager']])

# Standardization
x_train['Age'] = ss.fit_transform(x_train[['Age']]); x_test['Age'] = ss.transform(x_test[['Age']])
x_train['Education'] = ss.fit_transform(x_train[['Education']]); x_test['Education'] = ss.transform(x_test[['Education']])
x_train['EnvironmentSatisfaction'] = ss.fit_transform(x_train[['EnvironmentSatisfaction']]); x_test['EnvironmentSatisfaction'] = ss.transform(x_test[['EnvironmentSatisfaction']])
x_train['JobInvolvement'] = ss.fit_transform(x_train[['JobInvolvement']]); x_test['JobInvolvement'] = ss.transform(x_test[['JobInvolvement']])
x_train['JobLevel'] = ss.fit_transform(x_train[['JobLevel']]); x_test['JobLevel'] = ss.transform(x_test[['JobLevel']])
x_train['JobSatisfaction'] = ss.fit_transform(x_train[['JobSatisfaction']]); x_test['JobSatisfaction'] = ss.transform(x_test[['JobSatisfaction']])
x_train['OverTime'] = ss.fit_transform(x_train[['OverTime']]); x_test['OverTime'] = ss.transform(x_test[['OverTime']])
x_train['RelationshipSatisfaction'] = ss.fit_transform(x_train[['RelationshipSatisfaction']]); x_test['RelationshipSatisfaction'] = ss.transform(x_test[['RelationshipSatisfaction']])
x_train['StockOptionLevel'] = ss.fit_transform(x_train[['StockOptionLevel']]); x_test['StockOptionLevel'] = ss.transform(x_test[['StockOptionLevel']])
x_train['TrainingTimesLastYear'] = ss.fit_transform(x_train[['TrainingTimesLastYear']]); x_test['TrainingTimesLastYear'] = ss.transform(x_test[['TrainingTimesLastYear']])
x_train['WorkLifeBalance'] = ss.fit_transform(x_train[['WorkLifeBalance']]); x_test['WorkLifeBalance'] = ss.transform(x_test[['WorkLifeBalance']])

# %% [markdown]
# ## Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import precision_recall_curve

# %%
def model(classifier,x_train,y_train,x_test,y_test):
    
    classifier.fit(x_train,y_train)
    prediction = classifier.predict(x_test)
    cv = RepeatedStratifiedKFold(n_splits = 10,n_repeats = 3,random_state = 1)
    print("Cross Validation Score : ",'{0:.2%}'.format(cross_val_score(classifier,x_train,y_train,cv = cv,scoring = 'roc_auc').mean()))
def model_evaluation(classifier,x_test,y_test):
    
    # Confusion Matrix
    cm = confusion_matrix(y_test,classifier.predict(x_test))
    names = ['True Neg','False Pos','False Neg','True Pos']
    counts = [value for value in cm.flatten()]
    percentages = ['{0:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(names,counts,percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm,annot = labels,cmap = colors,fmt ='')
    
    # Classification Report
    print(classification_report(y_test,classifier.predict(x_test)))

# %% [markdown]
# XGBoost

# %%
from xgboost import XGBClassifier
classifier_xgb = XGBClassifier(learning_rate= 0.01,max_depth = 3,n_estimators = 1000)
model(classifier_xgb,x_train.values,y_train.values,x_test.values,y_test.values)
model_evaluation(classifier_xgb,x_test.values,y_test.values)
# Out:
# Cross Validation Score :  79.79%
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       189
#            1       0.50      0.31      0.38        32
#
#     accuracy                           0.86       221
#    macro avg       0.70      0.63      0.65       221
# weighted avg       0.83      0.86      0.84       221

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifier_dt = DecisionTreeClassifier(random_state = 1000,max_depth = 4,min_samples_leaf = 1)
model(classifier_dt,x_train.values,y_train.values,x_test.values,y_test.values)
model_evaluation(classifier_dt,x_test.values,y_test.values)
# Out:
# Cross Validation Score :  68.29%
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       189
#            1       0.50      0.28      0.36        32
#
#     accuracy                           0.86       221
#    macro avg       0.69      0.62      0.64       221
# weighted avg       0.83      0.86      0.84       221

# %% [markdown]
# Randomm Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf = RandomForestClassifier(max_depth = 4,random_state = 0)
model(classifier_rf,x_train.values,y_train.values,x_test.values,y_test.values)
model_evaluation(classifier_rf,x_test.values,y_test.values)
# Out:
# Cross Validation Score :  78.20%
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       189
#            1       0.43      0.09      0.15        32
#
#     accuracy                           0.85       221
#    macro avg       0.65      0.54      0.54       221
# weighted avg       0.80      0.85      0.81       221

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression(random_state=0)
model(log_model,x_train.values,y_train.values,x_test.values,y_test.values)
model_evaluation(log_model,x_test.values,y_test.values)
# Out:
# c:\Users\thian\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\thian\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
import joblib

# Save the XGBClassifier model to a file
joblib.dump(classifier_xgb, 'xgb_model.pkl')
print("Model saved as xgb_model.pkl")
# Out:
# Model saved as xgb_model.pkl
